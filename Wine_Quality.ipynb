# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls

# %%
df = pd.read_csv('C:\\Users\\Darshan\\Desktop\\winequalityN.csv')

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.shape
# Out:
# (6497, 13)

# %%
# Statistical Information about Dataset

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
# Additional Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 6492    False
# 6493    False
# 6494     True
# 6495    False
# 6496    False
# Length: 6497, dtype: bool

# %%
df['pH'].value_counts()
# Out:
# 3.16    200
# 3.14    193
# 3.22    185
# 3.20    176
# 3.15    170
#        ...
# 2.72      1
# 3.85      1
# 3.82      1
# 3.81      1
# 3.79      1
# Name: pH, Length: 108, dtype: int64

# %%
#Replacing null values with mean

df['fixed acidity'] = df['fixed acidity'].fillna(df['fixed acidity'].mean())
df['volatile acidity'] = df['volatile acidity'].fillna(df['volatile acidity'].mean())
df['citric acid'] = df['citric acid'].fillna(df['citric acid'].mean())
df['residual sugar'] = df['residual sugar'].fillna(df['residual sugar'].mean())
df['chlorides'] = df['chlorides'].fillna(df['chlorides'].mean())
df['pH'] = df['pH'].fillna(df['pH'].mean())
df['sulphates'] = df['sulphates'].fillna(df['sulphates'].mean())

# %%
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
fig, arr = plt.subplots(6,2, figsize = (10,8), dpi = 300)
sns.boxplot(x= 'type', y= 'fixed acidity', hue = 'type', data = df, ax = arr[0][0])
sns.boxplot(x= 'type', y= 'volatile acidity', hue = 'type', data = df, ax = arr[0][1])
sns.boxplot(x= 'type', y= 'citric acid', hue = 'type', data = df, ax = arr[1][0])
sns.boxplot(x= 'type', y= 'residual sugar', hue = 'type', data = df, ax = arr[1][1])
sns.boxplot(x= 'type', y= 'chlorides', hue = 'type', data = df, ax = arr[2][0])
sns.boxplot(x= 'type', y= 'free sulfur dioxide', hue = 'type', data = df, ax = arr[2][1])
sns.boxplot(x= 'type', y= 'total sulfur dioxide', hue = 'type', data = df, ax = arr[3][0])
sns.boxplot(x= 'type', y= 'density', hue = 'type', data = df, ax = arr[3][1])
sns.boxplot(x= 'type', y= 'pH', hue = 'type', data = df, ax = arr[4][0])
sns.boxplot(x= 'type', y= 'sulphates', hue = 'type', data = df, ax = arr[4][1])
sns.boxplot(x= 'type', y= 'alcohol', hue = 'type', data = df, ax = arr[5][0])
sns.boxplot(x= 'type', y= 'quality', hue = 'type', data = df, ax = arr[5][1])
# Out:
# <AxesSubplot:xlabel='type', ylabel='quality'>

# %%
# Exploratory Data Analysis

fig , ax = plt.subplots(ncols= 6, nrows = 2,figsize=(20,10))
index = 0
ax = ax.flatten()
for col,values in df.items():
    if col!= 'type':
        sns.boxplot(y= col,data = df, ax = ax[index])
        index = index+1

# %%
fig , ax = plt.subplots(ncols= 6, nrows = 2,figsize=(20,10))
index = 0
ax = ax.flatten()
for col,values in df.items():
    if col!= 'type':
        sns.distplot(values, ax = ax[index])
        index = index+1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...

# %%
df['free sulfur dioxide'] = np.log(1 + df['free sulfur dioxide'])
sns.distplot(df['free sulfur dioxide'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %% [markdown]
# Observation:
#     From above graph we can conclude that data of free sulfur dioxide is almost correct as it gives us the Bell Curve shape.

# %%
sns.countplot(df['type'], alpha = 0.75)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# Observation:
#     From the above graph we can say that peoples are used to take white wines as compare to red wines.

# %%
sns.countplot(df['quality'], alpha = 0.75)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# Observations:
#     1. The graph shows that the quality of wines are in between range of 3 to 9 in this dataset
#     2. The wine quality is fall under 5 6 and 7 range and for 3 and 9 are very few in numbers.

# %%
# Correlation

corr = df.corr()
plt.figure(figsize = (20,10))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation:
#     Above matrix states that the free sulfur dioxide and total sulfur dioxide are correlated with each other as their corr value is 0.75 which is nearest to 1..

# %%
sns.countplot(df['alcohol'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='alcohol', ylabel='count'>

# %% [markdown]
# Observation:
#     Above graph gives the ingrediant of alcohol in the wine.

# %%
plt.figure(figsize = (20,10))
sns.histplot(x= 'alcohol', data = df, bins = 100)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>
